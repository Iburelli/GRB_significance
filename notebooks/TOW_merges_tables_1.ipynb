# %%
import numpy as np

# %%
output='Events.merged.North.noMoon.thresh10.npy'
path='examples'
outfile=f'{path}/{output}'
filename=[]
for l in range (0,3):
    filename.append(f'{path}/Events_{100*l+1}_{100*(l+1)}.North.noMoon.thresh10.hidden.npy')
    
filename
# Out:
# ['examples/Events_1_100.North.noMoon.thresh10.hidden.npy',
#  'examples/Events_101_200.North.noMoon.thresh10.hidden.npy',
#  'examples/Events_201_300.North.noMoon.thresh10.hidden.npy']

# %%
Events_merged={}
for file in filename:
    data=np.load(file,allow_pickle=True, encoding='latin1', fix_imports=True).flat[0]
    Events_merged|=data

np.save(outfile,Events_merged)

# %%
data=np.load(output,allow_pickle=True, encoding='latin1', fix_imports=True).flat[0]
events = list(data.keys())
sites = list(data[events[0]].keys())
print(f'These are the parent keywords: \n\t{sorted(data.keys())}')
events = list(data.keys())
print(f'Inside each of the parent keyword you will find the following keys: \n\t{sorted(data[events[0]].keys())}')
sites = list(data[events[0]].keys())
print(f'Each key is a dictionary: \n\t{data[events[0]][sites[0]].keys()}')
# Out:
# These are the parent keywords:
# 	['Event1', 'Event10', 'Event100', 'Event101', 'Event102', 'Event103', 'Event104', 'Event105', 'Event106', 'Event107', 'Event108', 'Event109', 'Event11', 'Event110', 'Event111', 'Event112', 'Event113', 'Event114', 'Event115', 'Event116', 'Event117', 'Event118', 'Event119', 'Event12', 'Event120', 'Event121', 'Event122', 'Event123', 'Event124', 'Event125', 'Event126', 'Event127', 'Event128', 'Event129', 'Event13', 'Event130', 'Event131', 'Event132', 'Event133', 'Event134', 'Event135', 'Event136', 'Event137', 'Event138', 'Event139', 'Event14', 'Event140', 'Event141', 'Event142', 'Event143', 'Event144', 'Event145', 'Event146', 'Event147', 'Event148', 'Event149', 'Event15', 'Event150', 'Event151', 'Event152', 'Event153', 'Event154', 'Event155', 'Event156', 'Event157', 'Event158', 'Event159', 'Event16', 'Event160', 'Event161', 'Event162', 'Event163', 'Event164', 'Event165', 'Event166', 'Event167', 'Event168', 'Event169', 'Event17', 'Event170', 'Event171', 'Event172', 'Event173', 'Event174', 'Event175', 'Event176', 'Event177', 'Event178', 'Event179', 'Event18', 'Event180', 'Event181', 'Event182', 'Event183', 'Event184', 'Event185', 'Event186', 'Event187', 'Event188', 'Event189', 'Event19', 'Event190', 'Event191', 'Event192', 'Event193', 'Event194', 'Event195', 'Event196', 'Event197', 'Event198', 'Event199', 'Event2', 'Event20', 'Event200', 'Event201', 'Event202', 'Event203', 'Event204', 'Event205', 'Event206', 'Event207', 'Event208', 'Event209', 'Event21', 'Event210', 'Event211', 'Event212', 'Event213', 'Event214', 'Event215', 'Event216', 'Event217', 'Event218', 'Event219', 'Event22', 'Event220', 'Event221', 'Event222', 'Event223', 'Event224', 'Event225', 'Event226', 'Event227', 'Event228', 'Event229', 'Event23', 'Event230', 'Event231', 'Event232', 'Event233', 'Event234', 'Event235', 'Event236', 'Event237', 'Event238', 'Event239', 'Event24', 'Event240', 'Event241', 'Event242', 'Event243', 'Event244', 'Event245', 'Event246', 'Event247', 'Event248', 'Event249', 'Event25', 'Event250', 'Event251', 'Event252', 'Event253', 'Event254', 'Event255', 'Event256', 'Event257', 'Event258', 'Event259', 'Event26', 'Event260', 'Event261', 'Event262', 'Event263', 'Event264', 'Event265', 'Event266', 'Event267', 'Event268', 'Event269', 'Event27', 'Event270', 'Event271', 'Event272', 'Event273', 'Event274', 'Event275', 'Event276', 'Event277', 'Event278', 'Event279', 'Event28', 'Event280', 'Event281', 'Event282', 'Event283', 'Event284', 'Event285', 'Event286', 'Event287', 'Event288', 'Event289', 'Event29', 'Event290', 'Event291', 'Event292', 'Event293', 'Event294', 'Event295', 'Event296', 'Event297', 'Event298', 'Event299', 'Event3', 'Event30', 'Event300', 'Event31', 'Event32', 'Event33', 'Event34', 'Event35', 'Event36', 'Event37', 'Event38', 'Event39', 'Event4', 'Event40', 'Event41', 'Event42', 'Event43', 'Event44', 'Event45', 'Event46', 'Event47', 'Event48', 'Event49', 'Event5', 'Event50', 'Event51', 'Event52', 'Event53', 'Event54', 'Event55', 'Event56', 'Event57', 'Event58', 'Event59', 'Event6', 'Event60', 'Event61', 'Event62', 'Event63', 'Event64', 'Event65', 'Event66', 'Event67', 'Event68', 'Event69', 'Event7', 'Event70', 'Event71', 'Event72', 'Event73', 'Event74', 'Event75', 'Event76', 'Event77', 'Event78', 'Event79', 'Event8', 'Event80', 'Event81', 'Event82', 'Event83', 'Event84', 'Event85', 'Event86', 'Event87', 'Event88', 'Event89', 'Event9', 'Event90', 'Event91', 'Event92', 'Event93', 'Event94', 'Event95', 'Event96', 'Event97', 'Event98', 'Event99']
# Inside each of the parent keyword you will find the following keys:
# 	['North']
# Each key is a dictionary:
# 	dict_keys(['night01', 'first_night_start', 'night02'])

# %%
print(f'In example you can access data with a nested cycle:')
for n, event in enumerate(events):
    for site in sites:
        print(f'Template {event} - Site {site} ')
        if type(data[event][site]) == float:
            print(f'\tThis contains NaNs ---> the source is not observable due to daylight or moon.')
        else:
            print(f"\tSite keys are dictionaries containing details about single nights.")
            for night in data[event][site].keys():
                if night != 'first_night_start':
                    print(f"\n\t{night}:")
                    if type(data[event][site][night]['irf']) == float:
                        print(f'\tThis contains NaNs ---> the source is not observable at the site.')
                    else:
                        #print('\n')
                        print(f"\tStart time of single time intervals (here is printed just the first value):\n\t{round(data[event][site][night]['t_start'][0],2)}")
                        print(f"\tStop time of single time intervals (here is printed just the first value):\n\t{round(data[event][site][night]['t_stop'][0],2)}")
                        print(f"\tIrf associated to the interval:\n\t{data[event][site][night]['irf'][0]}")
                        print(f"\tSignificance calculated up to the interval stop time:\n\t{data[event][site][night]['significance'][0]}")
                        print(f"\tVariance associated to the significance:\n\t{data[event][site][night]['variance'][0]}")
                        print('\n')
    if n > 2:
        print("Let's stop after 3 templates.")
        break
# Out:
# In example you can access data with a nested cycle:
# Template Event1 - Site North
# 	Site keys are dictionaries containing details about single nights.
#
# 	night01:
# 	Start time of single time intervals (here is printed just the first value):
# 	30.0
# 	Stop time of single time intervals (here is printed just the first value):
# 	40.0
# 	Irf associated to the interval:
# 	North_z40_0.5h
# 	Significance calculated up to the interval stop time:
# 	0.31
# 	Variance associated to the significance:
# 	0.0
#
#
#
# 	night02:
# 	Start time of single time intervals (here is printed just the first value):
# 	64974.35
# 	Stop time of single time intervals (here is printed just the first value):
# 	64984.35
# 	Irf associated to the interval:
# 	North_z60_50h
# 	Significance calculated up to the interval stop time:
# 	13.0
# 	Variance associated to the significance:
# 	0.0
#
#
# Template Event10 - Site North
# 	Site keys are dictionaries containing details about single nights.
#
# 	night01:
# 	Start time of single time intervals (here is printed just the first value):
# 	8700.79
# 	Stop time of single time intervals (here is printed just the first value):
# 	8710.79
# 	Irf associated to the interval:
# 	North_z60_0.5h
# 	Significance calculated up to the interval stop time:
# 	0.0
# 	Variance associated to the significance:
# 	0.0
#
#
#
# 	night02:
# 	Start time of single time intervals (here is printed just the first value):
# 	95130.35
# 	Stop time of single time intervals (here is printed just the first value):
# 	95140.35
# 	Irf associated to the interval:
# 	North_z60_50h
# 	Significance calculated up to the interval stop time:
# 	2.86
# 	Variance associated to the significance:
# 	0.0
#
#
# Template Event100 - Site North
# 	Site keys are dictionaries containing details about single nights.
#
# 	night01:
# 	Start time of single time intervals (here is printed just the first value):
# 	30.0
# 	Stop time of single time intervals (here is printed just the first value):
# 	40.0
# 	Irf associated to the interval:
# 	North_z20_0.5h
# 	Significance calculated up to the interval stop time:
# 	0.74
# 	Variance associated to the significance:
# 	0.0
#
#
#
# 	night02:
# 	Start time of single time intervals (here is printed just the first value):
# 	73264.09
# 	Stop time of single time intervals (here is printed just the first value):
# 	73274.09
# 	Irf associated to the interval:
# 	North_z40_50h
# 	Significance calculated up to the interval stop time:
# 	6.51
# 	Variance associated to the significance:
# 	0.0
#
#
#
# 	night03:
# 	Start time of single time intervals (here is printed just the first value):
# 	159589.09
# 	Stop time of single time intervals (here is printed just the first value):
# 	159599.09
# 	Irf associated to the interval:
# 	North_z40_50h
# 	Significance calculated up to the interval stop time:
# 	5.54
# 	Variance associated to the significance:
# 	0.0
#
#
# Template Event11 - Site North
# 	Site keys are dictionaries containing details about single nights.
#
# 	night01:
# 	Start time of single time intervals (here is printed just the first value):
# 	30.0
# 	Stop time of single time intervals (here is printed just the first value):
# 	40.0
# 	Irf associated to the interval:
# 	North_z40_0.5h
# 	Significance calculated up to the interval stop time:
# 	0.31
# 	Variance associated to the significance:
# 	0.0
#
#
#
# 	night02:
# 	Start time of single time intervals (here is printed just the first value):
# 	74392.71
# 	Stop time of single time intervals (here is printed just the first value):
# 	74402.71
# 	Irf associated to the interval:
# 	North_z60_50h
# 	Significance calculated up to the interval stop time:
# 	5.13
# 	Variance associated to the significance:
# 	0.0
#
#
#
# 	night03:
# 	Start time of single time intervals (here is printed just the first value):
# 	160556.83
# 	Stop time of single time intervals (here is printed just the first value):
# 	160566.83
# 	Irf associated to the interval:
# 	North_z60_50h
# 	Significance calculated up to the interval stop time:
# 	3.98
# 	Variance associated to the significance:
# 	0.0
#
#
# Let's stop after 3 templates.
